# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns #import necessary libraries

# %%
df = pd.read_excel('/Users/zoephilipiyawa/PycharmProjects/pythonProject2/Credit_card.xlsx')
df
# Out:
#        Ind_ID  GENDER Car_Owner Property_Owner  CHILDREN  Annual_income  \
# 0     5008827    Male       Yes            Yes         0       180000.0
# 1     5008865  Female       Yes            Yes         2       135000.0
# 2     5008889  Female        No            Yes         0       247500.0
# 3     5009000    Male       Yes            Yes         0       157500.0
# 4     5009023  Female        No            Yes         2       216000.0
# ...       ...     ...       ...            ...       ...            ...
# 1543  5150038    Male        No             No         0       180000.0
# 1544  5150047  Female        No            Yes         0       283500.0
# 1545  5150164  Female        No             No         0       135000.0
# 1546  5150221    Male       Yes            Yes         0       116100.0
# 1547  5150412  Female        No            Yes         0        67500.0
#
#         Type_income         EDUCATION Marital_status           House_type  \
# ...

# %%
df['GENDER'] = df['GENDER'].astype('category') #convert datatype from string to category dtype.
df['GENDER'] = df['GENDER'].cat.codes # asseses the category value and assigns integer value
df # male = 1, female = 0
# Out:
#        Ind_ID  GENDER Car_Owner Property_Owner  CHILDREN  Annual_income  \
# 0     5008827       1       Yes            Yes         0       180000.0
# 1     5008865       0       Yes            Yes         2       135000.0
# 2     5008889       0        No            Yes         0       247500.0
# 3     5009000       1       Yes            Yes         0       157500.0
# 4     5009023       0        No            Yes         2       216000.0
# ...       ...     ...       ...            ...       ...            ...
# 1543  5150038       1        No             No         0       180000.0
# 1544  5150047       0        No            Yes         0       283500.0
# 1545  5150164       0        No             No         0       135000.0
# 1546  5150221       1       Yes            Yes         0       116100.0
# 1547  5150412       0        No            Yes         0        67500.0
#
#         Type_income         EDUCATION Marital_status           House_type  \
# ...

# %%
df['Type_income'] = df['Type_income'].astype('category') #convert datatype from string to category dtype.
df['Type_income'] = df['Type_income'].cat.codes # asseses the category value and assigns integer value
df # 0 = associate, 1 = pensioner, 2 = state servant , 3 = working
# Out:
#        Ind_ID  GENDER Car_Owner Property_Owner  CHILDREN  Annual_income  \
# 0     5008827       1       Yes            Yes         0       180000.0
# 1     5008865       0       Yes            Yes         2       135000.0
# 2     5008889       0        No            Yes         0       247500.0
# 3     5009000       1       Yes            Yes         0       157500.0
# 4     5009023       0        No            Yes         2       216000.0
# ...       ...     ...       ...            ...       ...            ...
# 1543  5150038       1        No             No         0       180000.0
# 1544  5150047       0        No            Yes         0       283500.0
# 1545  5150164       0        No             No         0       135000.0
# 1546  5150221       1       Yes            Yes         0       116100.0
# 1547  5150412       0        No            Yes         0        67500.0
#
#       Type_income         EDUCATION Marital_status           House_type  \
# ...

# %%
df['Marital_status'] = df['Marital_status'].astype('category') #convert datatype from string to category dtype.
df['Marital_status'] = df['Marital_status'].cat.codes # asseses the category value and assigns integer value
df # 1 = married, 2 = seperated, 3 = single , 4 = widow
# Out:
#        Ind_ID  GENDER Car_Owner Property_Owner  CHILDREN  Annual_income  \
# 0     5008827       1       Yes            Yes         0       180000.0
# 1     5008865       0       Yes            Yes         2       135000.0
# 2     5008889       0        No            Yes         0       247500.0
# 3     5009000       1       Yes            Yes         0       157500.0
# 4     5009023       0        No            Yes         2       216000.0
# ...       ...     ...       ...            ...       ...            ...
# 1543  5150038       1        No             No         0       180000.0
# 1544  5150047       0        No            Yes         0       283500.0
# 1545  5150164       0        No             No         0       135000.0
# 1546  5150221       1       Yes            Yes         0       116100.0
# 1547  5150412       0        No            Yes         0        67500.0
#
#       Type_income         EDUCATION  Marital_status           House_type  \
# ...

# %%
df.rename({'Approved or not':'Approved_or_not'}, axis = 1,inplace = True) # rename column
df
# Out:
#        Ind_ID  GENDER Car_Owner Property_Owner  CHILDREN  Annual_income  \
# 0     5008827       1       Yes            Yes         0       180000.0
# 1     5008865       0       Yes            Yes         2       135000.0
# 2     5008889       0        No            Yes         0       247500.0
# 3     5009000       1       Yes            Yes         0       157500.0
# 4     5009023       0        No            Yes         2       216000.0
# ...       ...     ...       ...            ...       ...            ...
# 1543  5150038       1        No             No         0       180000.0
# 1544  5150047       0        No            Yes         0       283500.0
# 1545  5150164       0        No             No         0       135000.0
# 1546  5150221       1       Yes            Yes         0       116100.0
# 1547  5150412       0        No            Yes         0        67500.0
#
#       Type_income         EDUCATION  Marital_status           House_type  \
# ...

# %%
plt.scatter(df['Approved_or_not'],df['GENDER']) # create a scatter plot to identify correlation between variables
plt.ylabel('Gender')
plt.xlabel('Approved or declined')
plt.title('Gender VS Approval status')
# Out:
# Text(0.5, 1.0, 'Gender VS Approval status')

# %%
plt.scatter(df['Approved_or_not'],df['Marital_status'])
plt.ylabel('Marital status')
plt.xlabel('Approved or declined')
plt.title('Marital VS Approval status')
# Out:
# Text(0.5, 1.0, 'Marital VS Approval status')

# %%
plt.scatter(df['Approved_or_not'],df['CHILDREN'])
plt.ylabel('Num_of_chidren')
plt.xlabel('Approved or declined')
plt.title('Children VS Approval status')
# Out:
# Text(0.5, 1.0, 'Children VS Approval status')

# %%
plt.scatter(df['Approved_or_not'],df['Annual_income'])
plt.ylabel('Annual_income')
plt.xlabel('Approved or declined')
plt.title('Annual Icome VS Approval status')
# Out:
# Text(0.5, 1.0, 'Annual Icome VS Approval status')

# %%
plt.scatter(df['Approved_or_not'],df['Employed_days'])
plt.ylabel('Employed_days')
plt.xlabel('Approved or declined')
plt.title('Employment Status VS Approval status')
# Out:
# Text(0.5, 1.0, 'Employment Status VS Approval status')

# %%
df.corr(numeric_only = True)['Approved_or_not']  #identify correlation between the independent varibles and its dependent variables
# Out:
# Ind_ID             0.016796
# GENDER             0.027392
# CHILDREN          -0.021646
# Annual_income      0.027456
# Type_income       -0.067856
# Marital_status     0.057885
# Birthday_count    -0.045097
# Employed_days      0.031408
# Family_member     -0.030709
# Approved_or_not    1.000000
# Name: Approved_or_not, dtype: float64

# %%
pip install scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/b1/8d/cf392a56e24627093a467642c8b9263052372131359b570df29aaf4811ab/scikit_learn-1.5.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata
# ...
#   Obtaining dependency information for scipy>=1.6.0 from https://files.pythonhosted.org/packages/50/51/3aa6bcde60dec542c6b8363b6a871b02827a41f01ab9c0c9324464f8c4cd/scipy-1.14.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.7 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl.metadata
# ...

# %%
df.isnull().sum() # check for null values
# Out:
# Ind_ID              0
# GENDER              0
# Car_Owner           0
# Property_Owner      0
# CHILDREN            0
# Annual_income      23
# Type_income         0
# EDUCATION           0
# Marital_status      0
# House_type          0
# Birthday_count     22
# Employed_days       0
# Family_member       0
# Approved_or_not     0
# dtype: int64

# %%
df = df.dropna() #drop null values
df
# Out:
#        Ind_ID  GENDER Car_Owner Property_Owner  CHILDREN  Annual_income  \
# 0     5008827       1       Yes            Yes         0       180000.0
# 1     5008865       0       Yes            Yes         2       135000.0
# 2     5008889       0        No            Yes         0       247500.0
# 3     5009000       1       Yes            Yes         0       157500.0
# 4     5009023       0        No            Yes         2       216000.0
# ...       ...     ...       ...            ...       ...            ...
# 1543  5150038       1        No             No         0       180000.0
# 1544  5150047       0        No            Yes         0       283500.0
# 1545  5150164       0        No             No         0       135000.0
# 1546  5150221       1       Yes            Yes         0       116100.0
# 1547  5150412       0        No            Yes         0        67500.0
#
#       Type_income         EDUCATION  Marital_status           House_type  \
# ...

# %%
df.isnull().sum()
# Out:
# Ind_ID             0
# GENDER             0
# Car_Owner          0
# Property_Owner     0
# CHILDREN           0
# Annual_income      0
# Type_income        0
# EDUCATION          0
# Marital_status     0
# House_type         0
# Birthday_count     0
# Employed_days      0
# Family_member      0
# Approved_or_not    0
# dtype: int64

# %%
X = df[['GENDER','CHILDREN','Annual_income','Employed_days', 'Family_member', 'Type_income','Marital_status']]
Y = df['Approved_or_not'] # Separate the independent variables (features) from the dependent variable (target)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0) 
# Split the Data into Training and Testing Sets

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
regr = LinearRegression()

# %%
regr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Predicted_y_results = regr.predict(X_train) # Make predictions on the test set

# %%
Predicted_y_results
# Out:
# array([0.06335136, 0.11607902, 0.13888727, ..., 0.11830273, 0.05512301,
#        0.04076835])

# %%
r2 = r2_score(Y_train, Predicted_y_results) #how well the proportion of variances of dependent variable that can explain the independent variable 
r2
# Out:
# 0.014645129113870059

# %%
plt.scatter(Y_train, Predicted_y_results)
plt.title('Credit card approval predictions'.title())
plt.xlabel('Actual approval')
plt.ylabel('Predicted approval')
# Out:
# Text(0, 0.5, 'Predicted approval')
